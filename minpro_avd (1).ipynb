# %% [markdown]
# **Ravina Eka Adiya**
# **2409116078**

# %% [markdown]
# #**BUSINESS UNDERSTANDING**

# %% [markdown]
# ###**BUSINESS OBJECTIVE**

# %% [markdown]
# untuk mencapai tujuan bisnis yang telah ditetapkan, bisa dengan menggunakan wawasan dari analisis data untuk meningkatkan penjualan produk yang paling diminati, mengembangkan strategi pemasaran yang lebih personal dan berbasis data untuk meningkatkann interaksi pelanggan, menyediakan rekomendasi produk yang lebih akurat untuk meningkatkan kepuasan dan retensi pelanggan.

# %% [markdown]
# ###**Assess Situation**

# %% [markdown]
# untuk memahami kondisi bisnis saat ini, beberapa faktor utama yang perlu di evaluasi seperti :
# 1. persaingan di industri kecantikan, tren produk, dan preferensi konsumen.
# 2. evaluasi kategori produk yang paling banyak diminati dan kurang diminati.
# 3. kendala dalam mengelola data, perubahan tren pasar, dan perilaku pelanggan yang dinamis.

# %% [markdown]
# ###**Data Mining Goals**

# %% [markdown]
# tujuan utama dalam proses data mining meliputi prediksi tren produk, segmentasi pelanggan, optimasi harga, rekomendasi produk.

# %% [markdown]
# ###**Project Plan**

# %% [markdown]
# Agar analisis katalog produk Sociolla dapat memberikan manfaat maksimal, ada beberapa langkah-langkah perencanaan proyek yang dapat diusulkan yaitu, pengumpulan data, pembersihan dan persiapan data, menggunakan teknik machine learning atau statistik untuk mengidentifikasi tren dan preferensi pelanggan, visualisasi dan pelaporan, menerapkan hasil analisis ke dalam strategi bisnis Sociolla untuk meningkatkan efisiensi dan pertumbuhan, evaluasi dan pengukuran kinerja.

# %% [markdown]
# #**DATA PREPARATION**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/products_all_brands.csv")

# %%
df
# Out:
#            brand_name                  product_name  product_id  \
# 0             796_3ce       MULTI EYE COLOR PALETTE       97802
# 1             796_3ce               VELVET LIP TINT       97810
# 2             796_3ce                     LIP COLOR       97822
# 3             796_3ce  MINI MULTI EYE COLOR PALETTE       97833
# 4             796_3ce                    FACE BLUSH       97801
# ...               ...                           ...         ...
# 7631  273_yves-rocher    Ambre Noir Eau De Toilette        2158
# 7632  273_yves-rocher  Soin Stimulating Conditioner       64174
# 7633  273_yves-rocher              Repair Hair Mask       36357
# 7634  273_yves-rocher   Hand Cream Olive Petitgrain       36404
# 7635  273_yves-rocher                    Color Mask       64153
#
#       beauty_point_earned              price_range price_by_combinations  \
# 0                     130  Rp 555.000 - Rp 687.000                   NaN
# ...

# %% [markdown]
# ###**Struktur Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7636 entries, 0 to 7635
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   brand_name                    7636 non-null   object
#  1   product_name                  7636 non-null   object
#  2   product_id                    7636 non-null   int64
#  3   beauty_point_earned           7636 non-null   int64
#  4   price_range                   7636 non-null   object
#  5   price_by_combinations         4087 non-null   object
#  6   url                           7636 non-null   object
#  7   active_date                   5534 non-null   object
#  8   default_category              7636 non-null   object
#  9   categories                    7632 non-null   object
#  10  rating_types_str              7561 non-null   object
#  11  average_rating                7636 non-null   float64
# ...

# %% [markdown]
# ###**Statistik Deskriptif**

# %%
df.describe()
# Out:
#           product_id  beauty_point_earned  average_rating  total_reviews  \
# count    7636.000000          7636.000000     7636.000000    7636.000000
# mean    82903.974725            37.236773        3.517905     198.197617
# std     27257.173650            46.056962        2.000138     852.067365
# min        68.000000             0.000000        0.000000       0.000000
# 25%     75267.000000            10.000000        3.910714       1.000000
# 50%     91856.500000            20.000000        4.576923       9.000000
# 75%    101825.500000            50.000000        4.738155      76.000000
# max    109155.000000           610.000000        5.000000   21536.000000
#
#        total_recommended_count  total_repurchase_maybe_count  \
# count              7636.000000                   7636.000000
# mean                186.560503                     40.603457
# std                 803.185318                    169.473278
# min                   0.000000                      0.000000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                               product_id  beauty_point_earned  average_rating  \
# product_id                      1.000000             0.035291       -0.283509
# beauty_point_earned             0.035291             1.000000       -0.215440
# average_rating                 -0.283509            -0.215440        1.000000
# total_reviews                  -0.330197            -0.078399        0.121674
# total_recommended_count        -0.327720            -0.078050        0.122024
# total_repurchase_maybe_count   -0.362813            -0.079921        0.121294
# total_repurchase_no_count      -0.336581            -0.065945        0.093776
# total_repurchase_yes_count     -0.308646            -0.076663        0.120678
# total_in_wishlist              -0.225070            -0.042009        0.147279
#
#                               total_reviews  total_recommended_count  \
# product_id                        -0.330197                -0.327720
# ...

# %% [markdown]
# ###**Missing Value**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# brand_name                       0.000000
# product_name                     0.000000
# product_id                       0.000000
# beauty_point_earned              0.000000
# price_range                      0.000000
# price_by_combinations           46.477213
# url                              0.000000
# active_date                     27.527501
# default_category                 0.000000
# categories                       0.052383
# rating_types_str                 0.982190
# average_rating                   0.000000
# total_reviews                    0.000000
# average_rating_by_types         24.174961
# total_recommended_count          0.000000
# total_repurchase_maybe_count     0.000000
# total_repurchase_no_count        0.000000
# total_repurchase_yes_count       0.000000
# total_in_wishlist                0.000000
# dtype: float64

# %% [markdown]
# ada 3 kolom yang hilang atau tidak terbaca, maka diperlukan penanganan missing values.

# %% [markdown]
# melakukan pengecekan nilai kosong pada kolom price_by_combinations

# %%
df[df['price_by_combinations'].isnull()]
# Out:
#            brand_name                  product_name  product_id  \
# 0             796_3ce       MULTI EYE COLOR PALETTE       97802
# 1             796_3ce               VELVET LIP TINT       97810
# 2             796_3ce                     LIP COLOR       97822
# 3             796_3ce  MINI MULTI EYE COLOR PALETTE       97833
# 4             796_3ce                    FACE BLUSH       97801
# ...               ...                           ...         ...
# 7631  273_yves-rocher    Ambre Noir Eau De Toilette        2158
# 7632  273_yves-rocher  Soin Stimulating Conditioner       64174
# 7633  273_yves-rocher              Repair Hair Mask       36357
# 7634  273_yves-rocher   Hand Cream Olive Petitgrain       36404
# 7635  273_yves-rocher                    Color Mask       64153
#
#       beauty_point_earned              price_range price_by_combinations  \
# 0                     130  Rp 555.000 - Rp 687.000                   NaN
# ...

# %% [markdown]
# melakukan pengecekan nilai kosong pada kolom active_date

# %%
df[df['active_date'].isnull()]
# Out:
#            brand_name                           product_name  product_id  \
# 26           751_abib         Heartleaf Essence Calming Pump       91887
# 28           751_abib           Yuja Essence Vitalizing Pump       91209
# 34           751_abib      Rebalancing Emulsion Skin Booster       91886
# 35           751_abib         Rebalancing Toner Skin Booster       91885
# 43           751_abib       Pine Needle Pore Pad Clear Touch       91889
# ...               ...                                    ...         ...
# 7628  273_yves-rocher  Energizing Shower Gel Mango Coriander        2347
# 7629  273_yves-rocher                     Repair Conditioner       64172
# 7631  273_yves-rocher             Ambre Noir Eau De Toilette        2158
# 7632  273_yves-rocher           Soin Stimulating Conditioner       64174
# 7634  273_yves-rocher            Hand Cream Olive Petitgrain       36404
#
#       beauty_point_earned price_range price_by_combinations  \
# ...

# %% [markdown]
# melakukan pengecekan nilai kosong pada kolom average_rating_by_types

# %%
df[df['average_rating_by_types'].isnull()]
# Out:
#             brand_name                                   product_name  \
# 2              796_3ce                                      LIP COLOR
# 11             796_3ce                 Waterproof Mega Volume Mascara
# 15             796_3ce  [  3CEx TOILETPAPER]   MOOD RECIPE FACE BLUSH
# 20             796_3ce                                 Glaze Lip Tint
# 22             796_3ce                                  Plumping Lips
# ...                ...                                            ...
# 7594  14878_you-beauty                  YOU Radiance Up Series Bundle
# 7602  14878_you-beauty           [BUY 1 GET 1] YOU Colorland Lip Clay
# 7604  14878_you-beauty                         YOU Daily Serum Bundle
# 7619  14878_you-beauty          [Buy 1 Get 1] YOU Colorland Lip Stain
# 7622      15371_youvit                                 Collagen Drink
#
#       product_id  beauty_point_earned              price_range  \
# ...

# %% [markdown]
# melakukan imputasi pada kolom price by combinations

# %%
df['price_by_combinations'].dropna().describe()
# Out:
# count                     4087
# unique                    2969
# top       "Non Specify": 99990
# freq                        18
# Name: price_by_combinations, dtype: object

# %% [markdown]
# melakukan imputasi pada kolom active date

# %%
df['active_date'].dropna().describe()
# Out:
# count                         5534
# unique                        5534
# top       2022-10-03T03:30:06.681Z
# freq                             1
# Name: active_date, dtype: object

# %% [markdown]
# melakukan imputasi pada kolom average rating by types

# %%
df['average_rating_by_types'].dropna().describe()
# Out:
# count                                                  5790
# unique                                                 4761
# top       "star_effectiveness": 5; "star_packaging": 5; ...
# freq                                                    447
# Name: average_rating_by_types, dtype: object

# %% [markdown]
# ###**Duplicated Values**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [brand_name, product_name, product_id, beauty_point_earned, price_range, price_by_combinations, url, active_date, default_category, categories, rating_types_str, average_rating, total_reviews, average_rating_by_types, total_recommended_count, total_repurchase_maybe_count, total_repurchase_no_count, total_repurchase_yes_count, total_in_wishlist]
# Index: []

# %% [markdown]
# karna tidak ada data atau kolom yang ter duplikasi, maka tidak perlu penanganan.

# %% [markdown]
# ###**Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                         Persentase Outliers
# product_id                              12.414877
# beauty_point_earned                      4.740702
# average_rating                          24.292823
# total_reviews                           15.675746
# total_recommended_count                 15.610267
# total_repurchase_maybe_count            15.217391
# total_repurchase_no_count               14.575694
# total_repurchase_yes_count              15.374542
# total_in_wishlist                       11.825563

# %% [markdown]
# dikarenakan nilai beatuy point earned kurang dari 10%, maka diperlukan penanganan.

# %% [markdown]
# melakukan imputasi

# %%
columns_to_impute = ["beauty_point_earned"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# pengecekan ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                         Persentase Outliers
# product_id                              12.414877
# beauty_point_earned                      0.000000
# average_rating                          24.292823
# total_reviews                           15.675746
# total_recommended_count                 15.610267
# total_repurchase_maybe_count            15.217391
# total_repurchase_no_count               14.575694
# total_repurchase_yes_count              15.374542
# total_in_wishlist                       11.825563

# %%
df
# Out:
#            brand_name                  product_name  product_id  \
# 0             796_3ce       MULTI EYE COLOR PALETTE       97802
# 1             796_3ce               VELVET LIP TINT       97810
# 2             796_3ce                     LIP COLOR       97822
# 3             796_3ce  MINI MULTI EYE COLOR PALETTE       97833
# 4             796_3ce                    FACE BLUSH       97801
# ...               ...                           ...         ...
# 7631  273_yves-rocher    Ambre Noir Eau De Toilette        2158
# 7632  273_yves-rocher  Soin Stimulating Conditioner       64174
# 7633  273_yves-rocher              Repair Hair Mask       36357
# 7634  273_yves-rocher   Hand Cream Olive Petitgrain       36404
# 7635  273_yves-rocher                    Color Mask       64153
#
#       beauty_point_earned              price_range price_by_combinations  \
# 0                     110  Rp 555.000 - Rp 687.000                   NaN
# ...

# %% [markdown]
# ###**Inconsistent Data**

# %%
df
# Out:
#            brand_name                  product_name  product_id  \
# 0             796_3ce       MULTI EYE COLOR PALETTE       97802
# 1             796_3ce               VELVET LIP TINT       97810
# 2             796_3ce                     LIP COLOR       97822
# 3             796_3ce  MINI MULTI EYE COLOR PALETTE       97833
# 4             796_3ce                    FACE BLUSH       97801
# ...               ...                           ...         ...
# 7631  273_yves-rocher    Ambre Noir Eau De Toilette        2158
# 7632  273_yves-rocher  Soin Stimulating Conditioner       64174
# 7633  273_yves-rocher              Repair Hair Mask       36357
# 7634  273_yves-rocher   Hand Cream Olive Petitgrain       36404
# 7635  273_yves-rocher                    Color Mask       64153
#
#       beauty_point_earned              price_range price_by_combinations  \
# 0                     110  Rp 555.000 - Rp 687.000                   NaN
# ...

# %%
df["product_name"] = df["product_name"].str.upper()

# %%
df
# Out:
#            brand_name                  product_name  product_id  \
# 0             796_3ce       MULTI EYE COLOR PALETTE       97802
# 1             796_3ce               VELVET LIP TINT       97810
# 2             796_3ce                     LIP COLOR       97822
# 3             796_3ce  MINI MULTI EYE COLOR PALETTE       97833
# 4             796_3ce                    FACE BLUSH       97801
# ...               ...                           ...         ...
# 7631  273_yves-rocher    AMBRE NOIR EAU DE TOILETTE        2158
# 7632  273_yves-rocher  SOIN STIMULATING CONDITIONER       64174
# 7633  273_yves-rocher              REPAIR HAIR MASK       36357
# 7634  273_yves-rocher   HAND CREAM OLIVE PETITGRAIN       36404
# 7635  273_yves-rocher                    COLOR MASK       64153
#
#       beauty_point_earned              price_range price_by_combinations  \
# 0                     110  Rp 555.000 - Rp 687.000                   NaN
# ...

# %% [markdown]
# ###**Construct Data**

# %%
df["high_demand"] = df["total_reviews"] / (df["total_in_wishlist"] + 1)

print(df.head())
# Out:
#   brand_name                  product_name  product_id  beauty_point_earned  \
# 0    796_3ce       MULTI EYE COLOR PALETTE       97802                  110
# 1    796_3ce               VELVET LIP TINT       97810                   50
# 2    796_3ce                     LIP COLOR       97822                   60
# 3    796_3ce  MINI MULTI EYE COLOR PALETTE       97833                   80
# 4    796_3ce                    FACE BLUSH       97801                   60
#
#                price_range price_by_combinations  \
# 0  Rp 555.000 - Rp 687.000                   NaN
# 1               Rp 264.000                   NaN
# 2               Rp 317.000                   NaN
# 3               Rp 423.000                   NaN
# 4               Rp 300.000                   NaN
#
#                                                  url  \
# 0  https://www.sociolla.com/eyeshadow/69460-phan-...
# 1  https://www.sociolla.com/lip-cream/69468-son-k...
# ...

# %% [markdown]
# ###**Data Reduction**

# %%
df = df.drop('price_by_combinations', axis=1)

# %%
df
# Out:
#            brand_name                  product_name  product_id  \
# 0             796_3ce       MULTI EYE COLOR PALETTE       97802
# 1             796_3ce               VELVET LIP TINT       97810
# 2             796_3ce                     LIP COLOR       97822
# 3             796_3ce  MINI MULTI EYE COLOR PALETTE       97833
# 4             796_3ce                    FACE BLUSH       97801
# ...               ...                           ...         ...
# 7631  273_yves-rocher    AMBRE NOIR EAU DE TOILETTE        2158
# 7632  273_yves-rocher  SOIN STIMULATING CONDITIONER       64174
# 7633  273_yves-rocher              REPAIR HAIR MASK       36357
# 7634  273_yves-rocher   HAND CREAM OLIVE PETITGRAIN       36404
# 7635  273_yves-rocher                    COLOR MASK       64153
#
#       beauty_point_earned              price_range  \
# 0                     110  Rp 555.000 - Rp 687.000
# 1                      50               Rp 264.000
# ...

# %% [markdown]
# #**Visualisasi Data**

# %% [markdown]
# ##Brand dengan Rating tertinggi

# %%
brand_counts = df['brand_name'].value_counts().reset_index()
brand_counts.columns = ['brand_name', 'average_rating']

print(brand_counts.head(10))
# Out:
#             brand_name  average_rating
# 0            246_nivea             160
# 1           244_tammia             138
# 2         167_sociolla             135
# 3             611_safi             112
# 4        217_jacquelle             110
# 5           218_wardah             104
# 6          15575_etude             103
# 7      15301_eze-nails             100
# 8  134_real-techniques              99
# 9     14878_you-beauty              98

# %% [markdown]
# Visualisasi Bar Chart

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=brand_counts.head(10), x='brand_name', y='average_rating', palette='viridis')
plt.title('Top 10 Brand dengan Rating Tertinggi', fontsize=16)
plt.xlabel('Brand Name')
plt.ylabel('Average Rating')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-33-820cacfb5fe5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=brand_counts.head(10), x='brand_name', y='average_rating', palette='viridis')

# %% [markdown]
# ###**Insight**

# %% [markdown]
# Dari diagram, terlihat bahwa ada beberapa brand yang memiliki rata-rata tinggi, menunjukan produk mereka sangat disukai oleh pelanggan. Ada kemungkinan beberapa brand konsisten menjaga kualitas produk, sehingga costumer memberikan rating tinggi. Brand dengan rating tinggi bisa dijadikan ikon atau prioritas promosi, karena terbukti telah memuaskan pelanggan.

# %% [markdown]
# ###**Tindakan**

# %% [markdown]
# Tindakan yang dapat diambil :
# 1. Melakukan Kampanye promosi dengan menonjolkan keunggulan dari brand tersebut.
# 2. Menambahkan bundle produk dari brand ini untuk mendorong penjualan lintas produk.
# 3. Perluas stok dan variasi produk dari brand yang sudah dipercaya.
# 4. Fokus marketing di platfrom e-commerce untuk brand yang performanya baik menurut rating.
# 5. Monitor tren rating setiap bulan untuk melihat apakah ada peningkatan atau penurunan yang signifikan.

# %% [markdown]
# ##Brand dengan Produk terbanyak

# %%
plt.figure(figsize=(8, 5))
plt.scatter(df['total_repurchase_yes_count'], df['total_reviews'], c='pink', alpha=0.5)
plt.title('Total Pembelian vs Total Riview')
plt.xlabel('Total Pembelian')
plt.ylabel('Total Riview')
plt.show()

# %% [markdown]
# ##Insight

# %% [markdown]
# Semakin banyak review yang dimiliki sebuah produk, cenderung semakin tinggi juga jumlah pembelian ulangnya. Ini menandakan bahwa produk yang disukai mendorong pelanggan untuk beli lagi.

# %% [markdown]
# ##Tindakan

# %% [markdown]
# Tindakan yang bisa dilakukan :
# 1. Perbanyak stok produk tersebut, lakukan cross-selling dengan produk lain.
# 2. Dorong pelanggan untuk menulis review, misalnya dengan memberi poin reward atau diskon.
# 3. Fokus pada produk yang punya potensi jadi produk andalan, monitor pertumbuhan review dan repurchase.
